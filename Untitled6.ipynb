# %% [markdown]
# <a href="https://colab.research.google.com/github/Udhay2898/Cricket_stat/blob/Master/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Sets/Cricket Stat.csv')
df.head()
# Out:
#            Player  Match  Innings  Not Outs  Runs  Balls Faced  100s  50s  \
# 0  A Ashish Reddy     31       23         8   280          193     0    0
# 1      A Chandila     12        2         2     4            7     0    0
# 2        A Chopra      7        6         0    53           71     0    0
# 3     A Choudhary      5        3         2    25           20     0    0
# 4     A Dananjaya      1        1         1     4            5     0    0
#
#    Ducks  4s  ...  Maiden  Runs Given  Wkts  4 W   5 W  Catches  Stimping  \
# 0      0  17  ...       0         396    18     0    0        9         0
# 1      0   0  ...       0         242    11     1    0        7         0
# 2      0   7  ...       0           0     0     0    0        2         0
# 3      0   1  ...       2         144     5     0    0        0         0
# 4      0   0  ...       0          47     0     0    0        0         0
#
#    B Averag   B SR   Econ
# 0      22.0  14.56   9.07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560 entries, 0 to 559
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Player              560 non-null    object
#  1   Match               560 non-null    int64
#  2   Innings             560 non-null    int64
#  3   Not Outs            560 non-null    int64
#  4   Runs                560 non-null    int64
#  5   Balls Faced         560 non-null    int64
#  6   100s                560 non-null    int64
#  7   50s                 560 non-null    int64
#  8   Ducks               560 non-null    int64
#  9   4s                  560 non-null    int64
#  10  6s                  560 non-null    int64
#  11  Average             560 non-null    float64
#  12  SR                  560 non-null    float64
#  13  High Score          560 non-null    int64
#  14  Innings by Bowling  560 non-null    int64
#  15  Balls Bowled        560 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['Player', 'Match', 'Innings', 'Not Outs', 'Runs', 'Balls Faced', '100s',
#        '50s', 'Ducks', '4s', '6s', 'Average', 'SR', 'High Score',
#        'Innings by Bowling', 'Balls Bowled', 'Maiden', 'Runs Given', 'Wkts',
#        '4 W ', '5 W', 'Catches', 'Stimping', 'B Averag', 'B SR', 'Econ'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Player                 object
# Match                   int64
# Innings                 int64
# Not Outs                int64
# Runs                    int64
# Balls Faced             int64
# 100s                    int64
# 50s                     int64
# Ducks                   int64
# 4s                      int64
# 6s                      int64
# Average               float64
# SR                    float64
# High Score              int64
# Innings by Bowling      int64
# Balls Bowled            int64
# Maiden                  int64
# Runs Given              int64
# Wkts                    int64
# 4 W                     int64
# 5 W                     int64
# Catches                 int64
# Stimping                int64
# B Averag              float64
# B SR                  float64
# Econ                  float64
# dtype: object

# %%
df.describe()
# Out:
#             Match     Innings    Not Outs         Runs  Balls Faced  \
# count  560.000000  560.000000  560.000000   560.000000   560.000000
# mean    29.739286   20.607143    4.864286   395.423214   309.910714
# std     38.545560   32.728994    7.557967   852.949984   644.793938
# min      1.000000    0.000000    0.000000     0.000000     0.000000
# 25%      5.000000    2.000000    0.000000     8.000000    12.000000
# 50%     13.000000    7.000000    2.000000    53.500000    54.500000
# 75%     38.250000   22.000000    7.000000   295.500000   250.250000
# max    193.000000  189.000000   65.000000  5412.000000  4112.000000
#
#              100s         50s       Ducks          4s          6s  ...  \
# count  560.000000  560.000000  560.000000  560.000000  560.000000  ...
# mean     0.103571    1.987500    1.573214   36.280357   14.571429  ...
# std      0.511046    5.640213    2.392968   81.376870   34.518853  ...
# ...

# %%
df.isnull().any()
# Out:
# Player                False
# Match                 False
# Innings               False
# Not Outs              False
# Runs                  False
# Balls Faced           False
# 100s                  False
# 50s                   False
# Ducks                 False
# 4s                    False
# 6s                    False
# Average               False
# SR                    False
# High Score            False
# Innings by Bowling    False
# Balls Bowled          False
# Maiden                False
# Runs Given            False
# Wkts                  False
# 4 W                   False
# 5 W                   False
# Catches               False
# Stimping              False
# B Averag              False
# B SR                  False
# Econ                  False
# dtype: bool

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 555    False
# 556    False
# 557    False
# 558    False
# 559    False
# Length: 560, dtype: bool

# %%
df.duplicated() == 1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 555    False
# 556    False
# 557    False
# 558    False
# 559    False
# Length: 560, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Player                560
# Match                 118
# Innings                99
# Not Outs               36
# Runs                  283
# Balls Faced           270
# 100s                    7
# 50s                    30
# Ducks                  14
# 4s                    124
# 6s                     82
# Average               325
# SR                    409
# High Score            119
# Innings by Bowling     89
# Balls Bowled          235
# Maiden                 11
# Runs Given            306
# Wkts                   81
# 4 W                     5
# 5 W                     3
# Catches                64
# Stimping               17
# B Averag              302
# B SR                  249
# Econ                  267
# dtype: int64

# %%
for column in df.columns:
    unique_values = df[column].unique()
    print(f"{column}:\n {unique_values}\n")
# Out:
# Player:
#  ['A Ashish Reddy' 'A Chandila' 'A Chopra' 'A Choudhary' 'A Dananjaya'
#  'A Flintoff' 'A Kumble' 'A Mishra' 'A Mithun' 'A Mukund' 'A Nehra'
#  'A Nel' 'A Singh' 'A Symonds' 'A Uniyal' 'A Zampa' 'AA Bilakhia'
#  'AA Chavan' 'AA Jhunjhunwala' 'AA Kazi' 'AA Noffke' 'AB Agarkar'
#  'AB Barath' 'AB Dinda' 'AB McDonald' 'AB de Villiers' 'AC Blizzard'
#  'AC Gilchrist' 'AC Thomas' 'AC Voges' 'AD Hales' 'AD Mascarenhas'
#  'AD Mathews' 'AD Nath' 'AD Russell' 'AF Milne' 'AG Murtaza' 'AG Paunikar'
#  'AJ Finch' 'AJ Turner' 'AJ Tye' 'AL Menaria' 'AM Nayar' 'AM Rahane'
#  'AM Salvi' 'AN Ahmed' 'AN Ghosh' 'AP Dole' 'AP Majumdar' 'AP Tare'
#  'AR Bawne' 'AR Patel' 'AS Joseph' 'AS Rajpoot' 'AS Raut' 'AS Roy'
#  'AS Yadav' 'AT Rayudu' 'AUK Pathan' 'Abdur Razzak' 'Abhishek Sharma'
#  'Anand Rajan' 'Anirudh Singh' 'Ankit Sharma' 'Ankit Soni' 'Anureet Singh'
#  'Arshdeep Singh' 'Avesh Khan' 'Azhar Mahmood' 'B Akhil' 'B Chipli'
# ...

# %%
df = df.fillna(np.nan)

# %%
df = df.fillna(0)

# %%
df.columns
# Out:
# Index(['Player', 'Match', 'Innings', 'Not Outs', 'Runs', 'Balls Faced', '100s',
#        '50s', 'Ducks', '4s', '6s', 'Average', 'SR', 'High Score',
#        'Innings by Bowling', 'Balls Bowled', 'Maiden', 'Runs Given', 'Wkts',
#        '4 W ', '5 W', 'Catches', 'Stimping', 'B Averag', 'B SR', 'Econ'],
#       dtype='object')

# %%
TOP 10 Player
By  Player', 'Match', 'Innings', 'Not Outs', 'Runs', 'Balls Faced', '100s',
       '50s', 'Ducks', '4s', '6s', 'Average', 'SR', 'High Score',
       'Innings by Bowling', 'Balls Bowled', 'Maiden', 'Runs Given', 'Wkts',
       '4 W ', '5 W', 'Catches', 'Stimping', 'B Averag', 'B SR', 'Econ'


Comparison By Players
